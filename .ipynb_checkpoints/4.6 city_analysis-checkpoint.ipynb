# %%
import matplotlib.pyplot as plt

# 设置支持中文的字体（例如 SimHei），同时确保负号能正常显示
# plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['font.sans-serif'] = ['Times New Roman', 'SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np

df = pd.read_csv("../data/7.匹配时间/merged_output.csv")

# %%
df
# Out:
#                           案号        裁判日期  \
# 0        （2016）浙0109民初16975号    2001/1/1
# 1         （2017）浙0109民初3106号    2001/1/1
# 2         （2017）浙0109民初2322号    2001/1/1
# 3         （2017）浙0109民初2852号    2001/1/1
# 4             （2002）绍刑初字第75号    2002/2/5
# ...                      ...         ...
# 1577532     （2021）冀02民终6530号  2021-10-09
# 1577533   （2021）浙1003民初4612号  2021-10-19
# 1577534  （2021）浙0109民初14869号  2021-10-19
# 1577535     （2021）辽05民终1192号  2021-10-14
# 1577536     （2021）冀02民终6527号  2021-10-09
#
#                                                        当事人 province city  \
# 0                   陈波波,王雷,华安财产保险股份有限公司安徽分公司宿州中心支公司灵璧营销服务部      浙江省  杭州市
# 1                             施建康,姚路兴,中国人民财产保险股份有限公司杭州市分公司      浙江省  杭州市
# 2                                周水娥；谭继明；信达财产保险股份有限公司浙江分公司      浙江省  杭州市
# 3                  胡生羊；宋建国；杭州展铭钢铁有限公司；中国人民财产保险股份有限公司杭州市分公司      浙江省  杭州市
# 4                                                       朱某      浙江省  绍兴市
# ...                                                    ...      ...  ...
# 1577532  中国平安财产保险股份有限公司唐山中心支公司；韩国才；韩宝军；滦县金盛物流有限公司；中国平安财...      河北省  唐山市
# 1577533          王天米；陈龙剑；杭州志尚运输有限公司；中国人寿财产保险股份有限公司杭州市中心支公司      浙江省  台州市
# 1577534                        张斌；程磊磊；中国人民财产保险股份有限公司义乌市分公司      浙江省  杭州市
# 1577535                       中国人民财产保险股份有限公司沈阳市分公司；陈春福；张雪娇      辽宁省  本溪市
# 1577536  中国平安财产保险股份有限公司唐山中心支公司；王中锁；韩宝军；滦县金盛物流有限公司；中国平安财...      河北省  唐山市
#
#         district          specific_place  vehicle  death         lng  \
# 0            萧山区                横一线建一村路口      0.0    0.0  120.490977
# 1            萧山区           瓜沥镇坎山工农村新农村地方      1.0    0.0  120.417430
# 2            萧山区              临浦镇临浦电厂江塘处      1.0    0.0  120.256051
# 3            萧山区            青六线杨家桥南300米处      1.0    0.0  120.261186
# 4            柯桥区            104国道绍兴县柯桥地段      2.0    1.0  120.496143
# ...          ...                     ...      ...    ...         ...
# 1577532      滦州市   京哈高速公路北京方向165ｋｍ＋100ｍ处      0.0    0.0  116.306662
# 1577533      黄岩区      椒黄线325省道36KM＋423M处      1.0    0.0  121.268566
# 1577534      萧山区  G60沪昆高速往江西方向191公里500米处      0.0    0.0  120.267797
# 1577535  桓仁满族自治县           桓仁县女山大桥桥头路口路段      2.0    0.0  125.367544
# 1577536      滦州市   京哈高速公路北京方向165ｋｍ＋100ｍ处      0.0    0.0  116.306662
#
#                lat         case_dt_hour
# 0        30.300890  2016-06-30 09:00:00
# 1        30.183977  2013-12-28 15:00:00
# 2        30.050339  2014-10-26 13:00:00
# 3        30.173526  2015-12-05 11:00:00
# 4        30.077218  2001-11-07 06:00:00
# ...            ...                  ...
# 1577532  39.819220  2020-04-20 06:00:00
# 1577533  28.655334  2020-12-31 12:00:00
# 1577534  30.025697  2021-04-19 17:00:00
# 1577535  41.272925  2018-10-07 14:00:00
# 1577536  39.819220  2020-04-20 06:00:00
#
# [1577537 rows x 12 columns]

# %% [markdown]
# # 计算发生时间到判决时间的天数

# %%
# 1) 确保两列都是 datetime
df["裁判日期"] = pd.to_datetime(df["裁判日期"], errors="coerce")
df["case_dt_hour"] = pd.to_datetime(df["case_dt_hour"], errors="coerce")

# 2) 计算相差天数（case_dt_hour - 裁判日期）
#    - 用 .dt.days 得到“整数天”（向下取整到天）
df["judge_time"] = (df["裁判日期"] - df["case_dt_hour"]).dt.days

print("清理前剩余行数：", len(df))
# Out:
# 清理前剩余行数： 1577537

# %% [markdown]
# # 去除掉负数天数

# %%
# 3) 统计 judge_time 为负数的个数（会自动忽略 NaN）
neg_mask = df["judge_time"] < 0
neg_count = neg_mask.sum()
print("judge_time < 0 的行数：", neg_count)

# 3) 去掉 judge_time 为负数的行（保留 judge_time >= 0 或 NaN）
df = df.loc[~neg_mask].copy()

print("清理前剩余行数：", len(df))
# Out:
# judge_time < 0 的行数： 2138
# 清理前剩余行数： 1575399

# %%
df
# Out:
#                          案号       裁判日期                            当事人  \
# 4            （2002）绍刑初字第75号 2002-02-05                             朱某
# 6           （2002）绍刑初字第160号 2002-04-30                             万某
# 7           （2002）绍刑初字第157号 2002-04-24                             赵某
# 8           （2002）绍刑初字第120号 2002-04-01                             丁某
# 9           （2002）绍刑初字第129号 2002-04-29                             楚某
# ...                     ...        ...                            ...
# 520667    （2015）绍诸民初字第2484号        NaT   王洪槐,吴传正,中国太平洋财产保险股份有限公司浦江支公司
# 520668  （2015）佛顺法乐民初字第1791号        NaT  陈光球,周梓泉,紫金财产保险股份有限公司顺德支公司,张光清
# 520669     （2015）临民一初字第314号        NaT    贾自周,张顺强,阳光财产保险股份有限公司漯河中心支公司
# 520670    （2015）禹刑初字第00346号        NaT                            朱某甲
# 520671     （2015）东刑初字第1768号        NaT                             俞某
#
#        province city district           specific_place  vehicle  death  \
# 4           浙江省  绍兴市      柯桥区             104国道绍兴县柯桥地段      2.0    1.0
# 6           浙江省  绍兴市      柯桥区                  兰亭镇新桥地段      0.0    1.0
# 7           浙江省  绍兴市      柯桥区               柯桥山阴路立新村地段      2.0    1.0
# 8           浙江省  绍兴市      柯桥区           104国道线陶堰镇周家湾地段      0.0    1.0
# 9           浙江省  绍兴市      柯桥区  104国道1524KM+800M绍兴县陶堰地段      0.0    1.0
# ...         ...  ...      ...                      ...      ...    ...
# 520667      浙江省  诸暨市      牌头镇          杭金线089KM500M王旭村      1.0    0.0
# 520668      广东省  佛山市      顺德区        乐从镇水藤入村大道30号铺对开路段      0.0    0.0
# 520669      河南省  漯河市      临颍县                    十里铺路段      1.0    0.0
# 520670      安徽省  蚌埠市      禹会区          朝阳路淮河公路桥东侧桥面桥中段      1.0    1.0
# 520671      浙江省  金华市      东阳市                泗雅线驶入东仙线时      1.0    1.0
#
#                lng        lat        case_dt_hour  judge_time
# 4       120.496143  30.077218 2001-11-07 06:00:00        89.0
# 6       120.501952  30.089303 2001-12-17 14:00:00       133.0
# 7       120.448550  30.114761 2001-10-19 04:00:00       186.0
# 8       120.501952  30.089303 1997-05-11 10:00:00      1785.0
# 9       120.518635  30.052507 2001-08-30 04:00:00       241.0
# ...            ...        ...                 ...         ...
# 520667  120.099422  29.724112 2014-12-08 09:00:00         NaN
# 520668  113.095696  22.964188 2015-05-02 19:00:00         NaN
# 520669  113.967536  33.780156 2015-07-22 19:00:00         NaN
# 520670  117.359061  32.926753 2015-05-31 17:00:00         NaN
# 520671  120.248422  29.295861 2015-09-12 06:00:00         NaN
#
# [519247 rows x 13 columns]

# %% [markdown]
# # 空间连接到天地图城市

# %%
# 2) 读城市边界 GeoJSON
city_gdf = gpd.read_file("/Users/wl/Paper_First/202601交通数据集LLM/data/figure/china_geodata/中国_市_eng.shp")

# %%
city_gdf
# Out:
#     name         gb   name_eng  \
# 0    梅州市  156441400    MeiZhou
# 1    鄂州市  156420700      EZhou
# 2    吕梁市  156141100    LvLiang
# 3    舟山市  156330900   ZhouShan
# 4    朝阳市  156211300   ZhaoYang
# ..   ...        ...        ...
# 370  陇南市  156621200    LongNan
# 371  保山市  156530500    BaoShan
# 372  遂宁市  156510900    SuiNing
# 373  合肥市  156340100      HeFei
# 374  铜川市  156610200  TongChuan
#
#                                               geometry
# 0    POLYGON ((115.88406 24.92896, 115.89031 24.927...
# 1    POLYGON ((114.83199 30.5678, 114.82968 30.4732...
# 2    POLYGON ((111.20539 38.72164, 111.20739 38.712...
# 3    MULTIPOLYGON (((122.25205 29.69094, 122.23384 ...
# 4    POLYGON ((119.6002 42.27468, 119.60812 42.2503...
# ..                                                 ...
# 370  POLYGON ((105.24292 34.52701, 105.2453 34.5154...
# 371  POLYGON ((98.7239 25.82049, 98.7109 25.80695, ...
# 372  MULTIPOLYGON (((105.90684 30.48512, 105.91431 ...
# 373  POLYGON ((117.19746 32.52641, 117.20584 32.516...
# 374  POLYGON ((109.20601 35.56597, 109.21323 35.552...
#
# [375 rows x 4 columns]

# %%
# 转换经纬度

# 3) 只保留需要字段，修一下几何（可选但推荐）
city_gdf = city_gdf[["name_eng", "geometry"]].copy()
city_gdf["geometry"] = city_gdf["geometry"].buffer(0)  # 修复少量无效几何（常见且有效）

# 4) CRS 对齐（你的 geojson 通常是经纬度 WGS84，但有时 crs 为空）
#    点数据一定是 EPSG:4326（经纬度）
if city_gdf.crs is None:
    city_gdf = city_gdf.set_crs(epsg=4326)
else:
    city_gdf = city_gdf.to_crs(epsg=4326)

# 5) 把 lng/lat 转成数值，生成点 GeoDataFrame
df["lng"] = pd.to_numeric(df["lng"], errors="coerce")
df["lat"] = pd.to_numeric(df["lat"], errors="coerce")

points_gdf = gpd.GeoDataFrame(
    df[["lng", "lat"]].copy(),
    geometry=gpd.points_from_xy(df["lng"], df["lat"]),
    crs="EPSG:4326")

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# =========================
# 参数区：按需修改
# =========================
LNG_COL = "lng"
LAT_COL = "lat"
CITY_NAME_COL = "name_eng"          # city_gdf 里城市名称字段
OUTPUT_COL = "city_name"        # 写回 df 的列名

PREDICATE = "within"            # "within" 或 "intersects"
USE_NEAREST_FALLBACK = True     # 是否对 NaN 做 nearest 兜底
MAX_NEAREST_DIST_M = None       # e.g. 50000 表示 50km，None 表示不限制

# =========================
# 0) 基础清洗：经纬度有效性
# =========================
df = df.copy()

# 转数值，非法变 NaN
df[LNG_COL] = pd.to_numeric(df[LNG_COL], errors="coerce")
df[LAT_COL] = pd.to_numeric(df[LAT_COL], errors="coerce")

# 可选：过滤明显不合法的经纬度
valid_coord = (
    df[LNG_COL].between(-180, 180, inclusive="both") &
    df[LAT_COL].between(-90, 90, inclusive="both")
)

# =========================
# 1) 构建点 GeoDataFrame（WGS84）
# =========================
points_gdf = gpd.GeoDataFrame(
    df.loc[valid_coord].copy(),
    geometry=gpd.points_from_xy(df.loc[valid_coord, LNG_COL], df.loc[valid_coord, LAT_COL]),
    crs="EPSG:4326"
)

# =========================
# 2) 确保 city_gdf 有 CRS，并与点一致（用于 within/intersects）
# =========================
if city_gdf.crs is None:
    raise ValueError("city_gdf.crs is None：请先给城市面数据设置正确的 CRS（例如 EPSG:4326）。")

# 先把城市面转换到 EPSG:4326，以便和 points_gdf 做空间连接
city_4326 = city_gdf.to_crs(points_gdf.crs)

# =========================
# 3) 空间连接：点落在哪个城市面
# =========================
joined = gpd.sjoin(
    points_gdf,
    city_4326[[CITY_NAME_COL, "geometry"]],
    how="left",
    predicate=PREDICATE
)

# 处理：极少数一个点命中多个面 -> 取第一个
city_name = joined[CITY_NAME_COL].groupby(joined.index).first()

# 先创建输出列
df[OUTPUT_COL] = pd.NA
# 回填到原 df（对齐索引）
df.loc[city_name.index, OUTPUT_COL] = city_name

# =========================
# 4) nearest 兜底：只对仍是 NaN 的点做
# =========================
if USE_NEAREST_FALLBACK:
    mask_na = df[OUTPUT_COL].isna() & valid_coord

    if mask_na.any():
        # 只取需要兜底的点
        points_na = gpd.GeoDataFrame(
            df.loc[mask_na].copy(),
            geometry=gpd.points_from_xy(df.loc[mask_na, LNG_COL], df.loc[mask_na, LAT_COL]),
            crs="EPSG:4326"
        )

        # --- 关键修复：投影到米制 CRS 再 nearest（避免 warning & 距离更准确） ---
        # 自动估算一个适合此区域的 UTM CRS（单位：米）
        proj_crs = city_4326.estimate_utm_crs()

        points_proj = points_na.to_crs(proj_crs)
        city_proj = city_4326.to_crs(proj_crs)

        nearest = gpd.sjoin_nearest(
            points_proj,
            city_proj[[CITY_NAME_COL, "geometry"]],
            how="left",
            distance_col="nearest_dist_m"
        )

        # 如果你想限制最大兜底距离（比如海上点别硬匹配）
        if MAX_NEAREST_DIST_M is not None:
            nearest.loc[nearest["nearest_dist_m"] > MAX_NEAREST_DIST_M, CITY_NAME_COL] = pd.NA

        # --- 关键修复：按 index 对齐回填，避免 .values 顺序错位 ---
        df.loc[nearest.index, OUTPUT_COL] = nearest[CITY_NAME_COL]

# %%
df
# Out:
#                           案号       裁判日期  \
# 4             （2002）绍刑初字第75号 2002-02-05
# 6            （2002）绍刑初字第160号 2002-04-30
# 7            （2002）绍刑初字第157号 2002-04-24
# 8            （2002）绍刑初字第120号 2002-04-01
# 9            （2002）绍刑初字第129号 2002-04-29
# ...                      ...        ...
# 1577532     （2021）冀02民终6530号        NaT
# 1577533   （2021）浙1003民初4612号        NaT
# 1577534  （2021）浙0109民初14869号        NaT
# 1577535     （2021）辽05民终1192号        NaT
# 1577536     （2021）冀02民终6527号        NaT
#
#                                                        当事人 province city  \
# 4                                                       朱某      浙江省  绍兴市
# 6                                                       万某      浙江省  绍兴市
# 7                                                       赵某      浙江省  绍兴市
# 8                                                       丁某      浙江省  绍兴市
# 9                                                       楚某      浙江省  绍兴市
# ...                                                    ...      ...  ...
# 1577532  中国平安财产保险股份有限公司唐山中心支公司；韩国才；韩宝军；滦县金盛物流有限公司；中国平安财...      河北省  唐山市
# 1577533          王天米；陈龙剑；杭州志尚运输有限公司；中国人寿财产保险股份有限公司杭州市中心支公司      浙江省  台州市
# 1577534                        张斌；程磊磊；中国人民财产保险股份有限公司义乌市分公司      浙江省  杭州市
# 1577535                       中国人民财产保险股份有限公司沈阳市分公司；陈春福；张雪娇      辽宁省  本溪市
# 1577536  中国平安财产保险股份有限公司唐山中心支公司；王中锁；韩宝军；滦县金盛物流有限公司；中国平安财...      河北省  唐山市
#
#         district           specific_place  vehicle  death         lng  \
# 4            柯桥区             104国道绍兴县柯桥地段      2.0    1.0  120.496143
# 6            柯桥区                  兰亭镇新桥地段      0.0    1.0  120.501952
# 7            柯桥区               柯桥山阴路立新村地段      2.0    1.0  120.448550
# 8            柯桥区           104国道线陶堰镇周家湾地段      0.0    1.0  120.501952
# 9            柯桥区  104国道1524KM+800M绍兴县陶堰地段      0.0    1.0  120.518635
# ...          ...                      ...      ...    ...         ...
# 1577532      滦州市    京哈高速公路北京方向165ｋｍ＋100ｍ处      0.0    0.0  116.306662
# 1577533      黄岩区       椒黄线325省道36KM＋423M处      1.0    0.0  121.268566
# 1577534      萧山区   G60沪昆高速往江西方向191公里500米处      0.0    0.0  120.267797
# 1577535  桓仁满族自治县            桓仁县女山大桥桥头路口路段      2.0    0.0  125.367544
# 1577536      滦州市    京哈高速公路北京方向165ｋｍ＋100ｍ处      0.0    0.0  116.306662
#
#                lat        case_dt_hour  judge_time city_name
# 4        30.077218 2001-11-07 06:00:00        89.0  ShaoXing
# 6        30.089303 2001-12-17 14:00:00       133.0  ShaoXing
# 7        30.114761 2001-10-19 04:00:00       186.0  ShaoXing
# 8        30.089303 1997-05-11 10:00:00      1785.0  ShaoXing
# 9        30.052507 2001-08-30 04:00:00       241.0  ShaoXing
# ...            ...                 ...         ...       ...
# 1577532  39.819220 2020-04-20 06:00:00         NaN   BeiJing
# 1577533  28.655334 2020-12-31 12:00:00         NaN   TaiZhou
# 1577534  30.025697 2021-04-19 17:00:00         NaN  HangZhou
# 1577535  41.272925 2018-10-07 14:00:00         NaN     BenXi
# 1577536  39.819220 2020-04-20 06:00:00         NaN   BeiJing
#
# [1575399 rows x 14 columns]

# %%
# 筛选列
cols = ["death", "judge_time", "city_name"]
df = df[cols]

# %%
df
# Out:
#          death  judge_time city_name
# 4          1.0        89.0  ShaoXing
# 6          1.0       133.0  ShaoXing
# 7          1.0       186.0  ShaoXing
# 8          1.0      1785.0  ShaoXing
# 9          1.0       241.0  ShaoXing
# ...        ...         ...       ...
# 1577532    0.0         NaN   BeiJing
# 1577533    0.0         NaN   TaiZhou
# 1577534    0.0         NaN  HangZhou
# 1577535    0.0         NaN     BenXi
# 1577536    0.0         NaN   BeiJing
#
# [1575399 rows x 3 columns]

# %% [markdown]
# # 统计缺失值

# %%
# 统计 judge_time 和 death 是否有缺失值，以及缺失多少
cols = ["death", "judge_time"]

missing_cnt = df[cols].isna().sum()               # 每列缺失个数
missing_ratio = df[cols].isna().mean()            # 每列缺失比例(0~1)

missing_summary = pd.DataFrame({
    "missing_count": missing_cnt,
    "missing_ratio": missing_ratio
}).reset_index().rename(columns={"index": "column"})

print(missing_summary)

# 如果你还想看“任意一个字段缺失”的行数：
rows_with_missing = df[cols].isna().any(axis=1).sum()
print("rows_with_missing(death or judge_time):", rows_with_missing)
# Out:
#        column  missing_count  missing_ratio
# 0       death              3       0.000002
# 1  judge_time         856919       0.543938
# rows_with_missing(death or judge_time): 856920

# %% [markdown]
# # 清洗数据

# %%
df = df.copy()

df.loc[:, "death"] = pd.to_numeric(df["death"], errors="coerce")
df.loc[:, "judge_time"] = pd.to_numeric(df["judge_time"], errors="coerce")

# %%
df
# Out:
#          death  judge_time city_name
# 4          1.0        89.0  ShaoXing
# 6          1.0       133.0  ShaoXing
# 7          1.0       186.0  ShaoXing
# 8          1.0      1785.0  ShaoXing
# 9          1.0       241.0  ShaoXing
# ...        ...         ...       ...
# 1577532    0.0         NaN   BeiJing
# 1577533    0.0         NaN   TaiZhou
# 1577534    0.0         NaN  HangZhou
# 1577535    0.0         NaN     BenXi
# 1577536    0.0         NaN   BeiJing
#
# [1575399 rows x 3 columns]

# %% [markdown]
# # judge_time：算平均值（mean）
# # death_1_ratio：算该城市 death==1.0 的占比（= 1.0 的个数 / 该城市总数）
# # 保留每个城市的样本量 n

# %%
import numpy as np
import pandas as pd

# df: 包含 death, judge_time, city_name 三列

result = (df.groupby("city_name", as_index=False).agg(judge_time_mean=("judge_time", "mean"),n=("death", "size"),death_1_cnt=("death", lambda s: (s == 1.0).sum()),))

result["judge_time_mean"] = result["judge_time_mean"].round().astype("Int64")  # 可处理缺失值
result["death_1_ratio"] = result["death_1_cnt"] / result["n"]

# 如果你不想要 cnt，只想要占比，可以最后 drop 掉
result = result.drop(columns=["death_1_cnt"])

# result.to_csv('./TEST.csv')
result
# Out:
#             city_name  judge_time_mean      n  death_1_ratio
# 0    ABaZangZuQiangZu              339    299       0.575251
# 1               AKeSu              403    595       0.346218
# 2               ALaEr              320    222       0.324324
# 3             ALaShan              353    334       0.404192
# 4             ALeiTai              395    220       0.377273
# ..                ...              ...    ...            ...
# 361           ZhuZhou              343   2470       0.340486
# 362              ZiBo              300  10450       0.216746
# 363            ZiGong              359   1574       0.340534
# 364            ZiYang              258   1013       0.472853
# 365             ZunYi              312   5261       0.268200
#
# [366 rows x 4 columns]

# %% [markdown]
# # 筛选样本量 保留前30？或者不筛选

# %%
# 把 result 本身也直接变成前n条
result_top = result.sort_values(by='n', ascending=False).head(366).reset_index(drop=True)

result_top
# Out:
#                   city_name  judge_time_mean      n  death_1_ratio
# 0                  ShangHai              428  47851       0.103927
# 1                   BeiJing              336  33789       0.111012
# 2                   WeiFang              284  33270       0.199128
# 3                   TianJin              301  32611       0.135874
# 4                     LinYi              262  29298       0.252475
# ..                      ...              ...    ...            ...
# 361                KeKeDaLa              217     10       0.300000
# 362                ShuangHe              304      8       0.250000
# 363                 XinXing              498      7       0.428571
# 364                   KunYu              319      4       0.000000
# 365  LianHuaShanFengJingLin             <NA>      1       0.000000
#
# [366 rows x 4 columns]

# %% [markdown]
# # 绘制散点图

# %% [markdown]
# ## 案件数量 vs 判决天数

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

df = result_top.copy()
df = df.replace([np.inf, -np.inf], np.nan).dropna(subset=["n", "judge_time_mean", "city_name"])
df = df[df["n"] > 0]

x = df["n"].astype(float).to_numpy()
y = df["judge_time_mean"].astype(float).to_numpy()
labels = df["city_name"].astype(str).to_numpy()

# 线性回归：y = b0 + b1*x
X = sm.add_constant(x)
model = sm.OLS(y, X).fit()

# 拟合线 + 置信区间
x_grid = np.linspace(x.min(), x.max(), 300)
X_grid = sm.add_constant(x_grid)

pred = model.get_prediction(X_grid).summary_frame(alpha=0.05)  # 95% CI
y_hat = pred["mean"].to_numpy()
ci_low = pred["mean_ci_lower"].to_numpy()
ci_high = pred["mean_ci_upper"].to_numpy()

# ===== 颜色控制区域 =====
point_color = "#d1e5f5"
line_color  = "#d62728"
band_color  = "#d62728"
band_alpha  = 0.18
edge_color  = "#33729d"
# =======================

plt.figure(figsize=(5, 5),dpi=300)

# 散点
plt.scatter(
    x, y,
    s=13,
    c=point_color,
    edgecolors=edge_color,
    linewidths=0.5,
    alpha=1
)

# 拟合线
plt.plot(
    x_grid, y_hat,
    color=line_color,
    linewidth=1,
    linestyle="-"
)

# 区间带
plt.fill_between(
    x_grid, ci_low, ci_high,
    color=band_color,
    alpha=band_alpha,
    linewidth=0)

# ====== 标注 city_name ======
# 如果你担心 366 个城市都标注会太挤，可以把 annotate_all=False 并设置 top_n
annotate_all = True
top_n = 30  # annotate_all=False 时，标注 n 最大的前 top_n 个点（你也可以换成别的规则）

if annotate_all:
    idx_to_annotate = range(len(df))
else:
    idx_to_annotate = np.argsort(x)[-top_n:]  # 例：只标注 n 最大的 top_n

for i in idx_to_annotate:
    plt.annotate(
        labels[i],
        (x[i], y[i]),
        textcoords="offset points",
        xytext=(0, 3),           # 向上偏移 3 个点
        ha="center",
        va="bottom",
        fontsize=6,
        color="#2b2b2b",
        alpha=0.9,
        clip_on=True)
# ============================

plt.xlabel("Case Number")
plt.ylabel("Average Judgment Time")
plt.grid(True, alpha=0.3)

plt.savefig(
    '../data/figure/case_num_judge_time.png',
    # '../data/figure/case_num_judge_time_NOLABEL.png',
    dpi=300,
    bbox_inches='tight',
    pad_inches=0.1
)
plt.show()

# %% [markdown]
# ## 案件数量 vs 死亡率

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

df = result_top.copy()
df = df.replace([np.inf, -np.inf], np.nan).dropna(subset=["n", "death_1_ratio", "city_name"])
df = df[df["n"] > 0]

x = df["n"].astype(float).to_numpy()
y = df["death_1_ratio"].astype(float).to_numpy()
labels = df["city_name"].astype(str).to_numpy()

# 线性回归：y = b0 + b1*x
X = sm.add_constant(x)
model = sm.OLS(y, X).fit()

# 拟合线 + 置信区间
x_grid = np.linspace(x.min(), x.max(), 300)
X_grid = sm.add_constant(x_grid)

pred = model.get_prediction(X_grid).summary_frame(alpha=0.05)  # 95% CI
y_hat = pred["mean"].to_numpy()
ci_low = pred["mean_ci_lower"].to_numpy()
ci_high = pred["mean_ci_upper"].to_numpy()

# ===== 颜色控制区域 =====
point_color = "#d1e5f5"
line_color  = "#d62728"
band_color  = "#d62728"
band_alpha  = 0.18
edge_color  = "#33729d"
# =======================

plt.figure(figsize=(5, 5),dpi=300)

# 散点
plt.scatter(
    x, y,
    s=13,
    c=point_color,
    edgecolors=edge_color,
    linewidths=0.5,
    alpha=1
)

# 拟合线
plt.plot(
    x_grid, y_hat,
    color=line_color,
    linewidth=1,
    linestyle="-"
)

# 区间带
plt.fill_between(
    x_grid, ci_low, ci_high,
    color=band_color,
    alpha=band_alpha,
    linewidth=0)

# ====== 标注 city_name ======
# 如果你担心 366 个城市都标注会太挤，可以把 annotate_all=False 并设置 top_n
# annotate_all = True
# top_n = 30  # annotate_all=False 时，标注 n 最大的前 top_n 个点（你也可以换成别的规则）

# if annotate_all:
#     idx_to_annotate = range(len(df))
# else:
#     idx_to_annotate = np.argsort(x)[-top_n:]  # 例：只标注 n 最大的 top_n

# for i in idx_to_annotate:
#     plt.annotate(
#         labels[i],
#         (x[i], y[i]),
#         textcoords="offset points",
#         xytext=(0, 3),           # 向上偏移 3 个点
#         ha="center",
#         va="bottom",
#         fontsize=6,
#         color="#2b2b2b",
#         alpha=0.9,
#         clip_on=True)
# ============================

plt.xlabel("Case Number")
plt.ylabel("Case Death Rate")
plt.grid(True, alpha=0.3)
plt.ylim(0, 1) # 限制纵坐标轴的范围

plt.savefig(
    # '../data/figure/case_num_death_ratio.png',
    '../data/figure/case_num_death_ratio_NOLABEL.png',
    dpi=300,
    bbox_inches='tight',
    pad_inches=0.1
)
plt.show()
