# %% [markdown]
# # 读取文件

# %%
import pandas as pd

df = pd.read_csv("../data/6.匹配地点/address_transport_result_1_4.csv")
print(df.head())
# Out:
#                     案号        裁判日期                                      当事人  \
# 0  （2016）浙0109民初16975号  2001-01-01   陈波波,王雷,华安财产保险股份有限公司安徽分公司宿州中心支公司灵璧营销服务部
# 1   （2017）浙0109民初3106号  2001-01-01             施建康,姚路兴,中国人民财产保险股份有限公司杭州市分公司
# 2   （2017）浙0109民初2322号  2001-01-01                周水娥；谭继明；信达财产保险股份有限公司浙江分公司
# 3   （2017）浙0109民初2852号  2001-01-01  胡生羊；宋建国；杭州展铭钢铁有限公司；中国人民财产保险股份有限公司杭州市分公司
# 4       （2002）绍刑初字第75号  2002-02-05                                       朱某
#
#            case_time province city district specific_place  vehicle  death  \
# 0     2016年06月30日09时      浙江省  杭州市      萧山区       横一线建一村路口      0.0    0.0
# 1     2013年12月28日15时      浙江省  杭州市      萧山区  瓜沥镇坎山工农村新农村地方      1.0    0.0
# 2  2014年10月26日13时20分      浙江省  杭州市      萧山区     临浦镇临浦电厂江塘处      1.0    0.0
# 3   2015年12月5日11时40分      浙江省  杭州市      萧山区   青六线杨家桥南300米处      1.0    0.0
# 4   2001年11月7日06时50分      浙江省  绍兴市      柯桥区   104国道绍兴县柯桥地段      2.0    1.0
#
#           lng        lat level  ok
# 0  120.490977  30.300890    村庄   1
# 1  120.417430  30.183977  生活服务   1
# 2  120.256051  30.050339    商圈   1
# 3  120.261186  30.173526    道路   1
# 4  120.496143  30.077218    村庄   1

# %% [markdown]
# # 格式化时间

# %%
# 把原始 case_time 列统一转换成 pandas 的字符串类型（StringDtype），并去掉首尾空格
# 这样后面用正则提取时更稳健（避免因为空格导致匹配失败）
s = df["case_time"].astype("string").str.strip()

# 定义用于提取“年/月/日/时/分”的正则表达式（中文日期格式）
# 这里用“命名捕获组” (?P<name>...)，提取后会直接得到列名 year/month/day/hour/minute
pat = (
    r"(?P<year>\d{4})年"          # year: 4位数字，例如 2021年
    r"(?P<month>\d{1,2})月"       # month: 1~2位数字，例如 8月 或 08月
    r"(?P<day>\d{1,2})日"         # day: 1~2位数字，例如 16日
    r"(?P<hour>\d{1,2})时"        # hour: 1~2位数字，例如 11时
    r"(?:(?P<minute>\d{1,2})分)?" # minute: 可选（? 表示出现0次或1次）
                                 # 外层 (?:...) 是“非捕获组”，避免产生多余列
                                 # 如果没有“xx分”，minute 会是缺失值 NA
)

# 对 s 逐行应用正则提取：
# - 能匹配到的行：返回 year/month/day/hour/minute 五列（minute 可能为空）
# - 不能匹配的行（例如：只有“2021年”、未知、空）：对应列都是 NA
parts = s.str.extract(pat)

# 只保留“精确到小时”的记录：
# 要求 year/month/day/hour 这四个字段都不为空（notna）
# all(axis=1) 表示按行判断：这一行四列都非空才为 True
keep = parts[["year", "month", "day", "hour"]].notna().all(axis=1)

# 用 keep 过滤原始数据 df，得到符合条件的新表 df2
# copy() 复制一份，避免后续修改触发 SettingWithCopyWarning
df2 = df.loc[keep].copy()

# 同样过滤提取结果 parts，得到 parts2（与 df2 行一一对应）
parts2 = parts.loc[keep].copy()

# str.extract 得到的是字符串列（StringDtype），但 to_datetime 需要数值
# 所以把 year/month/day/hour/minute 统一转成数值：
# errors="coerce" 表示：遇到无法转换的内容就变成 NaN（而不是报错）
for c in ["year", "month", "day", "hour", "minute"]:
    parts2[c] = pd.to_numeric(parts2[c], errors="coerce")

# minute 是可选字段：
# - 如果原字符串没有“xx分”，minute 为 NaN
# - 我们希望保留这些记录，并把 minute 当成 0 分钟（整点）
# 因此先 fillna(0)，再转成 int64
parts2["minute"] = parts2["minute"].fillna(0).astype("int64")

# 生成 pandas datetime：
# pd.to_datetime 可以接收一个 dict（year/month/day/hour/minute），逐行组成时间
# errors="coerce" 表示：如果日期非法（比如 2021年13月40日），会变成 NaT 而不是报错
dt = pd.to_datetime(
    dict(
        year=parts2["year"].astype("int64"),   # 年转 int
        month=parts2["month"].astype("int64"), # 月转 int
        day=parts2["day"].astype("int64"),     # 日转 int
        hour=parts2["hour"].astype("int64"),   # 时转 int
        minute=parts2["minute"],               # 分已是 int64
    ),
    errors="coerce",
)

# 把生成好的 datetime 写回 df2
df2["case_dt"] = dt

# 再保险过滤一次：把无法生成 datetime 的行去掉（NaT）
df2 = df2[df2["case_dt"].notna()].copy()

# 截断到“小时”粒度：
# - 例如 2020-11-10 08:40 -> 2020-11-10 08:00
# - 原本就是整点（minute=0）的不会变
# 方便做小时分布统计（0-23点、或按时间序列聚合）
df2["case_dt_hour"] = df2["case_dt"].dt.floor("H")
# Out:
# /var/folders/9f/lczvn2yj5xq7blvk6mz2y_lh0000gn/T/ipykernel_61816/3242918298.py:70: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df2["case_dt_hour"] = df2["case_dt"].dt.floor("H")

# %%
df2
# Out:
#                          案号        裁判日期  \
# 0       （2016）浙0109民初16975号  2001-01-01
# 1        （2017）浙0109民初3106号  2001-01-01
# 2        （2017）浙0109民初2322号  2001-01-01
# 3        （2017）浙0109民初2852号  2001-01-01
# 4            （2002）绍刑初字第75号  2002-02-05
# ...                     ...         ...
# 286662    （2014）金民一初字第2666号  2014-11-13
# 286663    （2014）陇民初字第00656号  2014-11-03
# 286664    （2014）永冷民初字第1409号  2014-11-30
# 286665     （2014）镇民初字第1929号  2014-11-25
# 286666     （2014）四民初字第号297号  2014-11-14
#
#                                             当事人          case_time province  \
# 0        陈波波,王雷,华安财产保险股份有限公司安徽分公司宿州中心支公司灵璧营销服务部     2016年06月30日09时      浙江省
# 1                  施建康,姚路兴,中国人民财产保险股份有限公司杭州市分公司     2013年12月28日15时      浙江省
# 2                     周水娥；谭继明；信达财产保险股份有限公司浙江分公司  2014年10月26日13时20分      浙江省
# 3       胡生羊；宋建国；杭州展铭钢铁有限公司；中国人民财产保险股份有限公司杭州市分公司   2015年12月5日11时40分      浙江省
# 4                                            朱某   2001年11月7日06时50分      浙江省
# ...                                         ...                ...      ...
# 286662    殷某,张某某,马某某,梁某某,中国人寿财产保险股份有限公司郑州市中心支公司     2014年06月22日07时      河南省
# 286663       曹记雄,桑陇刚,安邦财产保险股份有限公司宝鸡中心支公司陇县营销服务部  2013年11月14日12时40分      陕西省
# 286664          罗国华,康爱军,彭伟,中国人民财产保险股份有限公司永州市分公司     2014年05月29日14时      湖南省
# 286665             郭潇,张华东,中国大地财产保险股份有限公司南阳中心支公司     2014年08月22日10时      河南省
# 286666                                 徐某某,某某公司  2013年10月30日18时30分      内蒙古
#
#         city district                specific_place  vehicle  death  \
# 0        杭州市      萧山区                      横一线建一村路口      0.0    0.0
# 1        杭州市      萧山区                 瓜沥镇坎山工农村新农村地方      1.0    0.0
# 2        杭州市      萧山区                    临浦镇临浦电厂江塘处      1.0    0.0
# 3        杭州市      萧山区                  青六线杨家桥南300米处      1.0    0.0
# 4        绍兴市      柯桥区                  104国道绍兴县柯桥地段      2.0    1.0
# ...      ...      ...                           ...      ...    ...
# 286662   郑州市      金水区                      紫荆山路东里路口      1.0    1.0
# 286663   宝鸡市       陇县   陇县南大街由北向南行驶至新建路十字路段左转驶入陇凤路时      2.0    0.0
# 286664   永州市     冷水滩区               永州市教育局对面的银珊宾馆路段      1.0    0.0
# 286665   南阳市      镇平县  镇平西建设大道自东向西行驶至“开发区台区北干〇五”线杆处      2.0    0.0
# 286666  四子王旗      NaN          乌兰花——江岸公路9KM＋700M路段处      1.0    0.0
#
#                lng        lat level  ok             case_dt  \
# 0       120.490977  30.300890    村庄   1 2016-06-30 09:00:00
# 1       120.417430  30.183977  生活服务   1 2013-12-28 15:00:00
# 2       120.256051  30.050339    商圈   1 2014-10-26 13:20:00
# 3       120.261186  30.173526    道路   1 2015-12-05 11:40:00
# 4       120.496143  30.077218    村庄   1 2001-11-07 06:50:00
# ...            ...        ...   ...  ..                 ...
# 286662  113.700284  34.758191  地产小区   1 2014-06-22 07:00:00
# 286663  106.842883  34.899993    道路   1 2013-11-14 12:40:00
# 286664  111.597146  26.460664    宾馆   1 2014-05-29 14:00:00
# 286665  112.241148  33.038940    购物   1 2014-08-22 10:00:00
# 286666  111.712996  41.539471  政府机构   1 2013-10-30 18:30:00
#
#               case_dt_hour
# 0      2016-06-30 09:00:00
# 1      2013-12-28 15:00:00
# 2      2014-10-26 13:00:00
# 3      2015-12-05 11:00:00
# 4      2001-11-07 06:00:00
# ...                    ...
# 286662 2014-06-22 07:00:00
# 286663 2013-11-14 12:00:00
# 286664 2014-05-29 14:00:00
# 286665 2014-08-22 10:00:00
# 286666 2013-10-30 18:00:00
#
# [245580 rows x 16 columns]

# %% [markdown]
# # 导出检查数据

# %% [raw]
# # 不保留 pandas 的行索引列（推荐）
# df2.to_csv("../data/6.匹配地点时间/time_transport_result_1w.csv",index=False,encoding="utf-8-sig")

# %%
# 筛选列 进行保存
cols = ["案号", "裁判日期", "当事人", 
        "province", "city", "district", "specific_place",
        "vehicle", "death",
        "lng", "lat", 
        "case_dt_hour"]

df2[cols].to_csv("../data/7.匹配时间/time_transport_result_1_4.csv",index=False,encoding="utf-8-sig")
